# %%
import results.DampAndDiscountBPEngine
import pandas as pd
df= pd.read_csv("results/DampAndDiscountBPEngine/BPEngine_df0.9.csv",header=None)
df2=pd.read_csv("../results/BPEngine/BPEngine.csv", header=None)
df3= pd.read_csv("../results/CostReductionOnceEngine/BPEngine_cr0.5.csv", header=None)

# %% [markdown]
# ## Plot Resault of a single run

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(10,5))
plt.plot(df[0])
plt.plot(df2[0])
plt.plot(df3[0])
plt.xlabel("cycle num")
plt.ylabel('Cost')
plt.title('Cost vs Cycle')
plt.show()
